# %%
import openpyxl
dataframe=openpyxl.load_workbook("pk.xlsx")
dataframe1= dataframe.active

for row in range(0, dataframe1.max_row):
    for col in dataframe1.iter_cols(1,dataframe1.max_column):
        print(col[row].value)
# Out:
#  PK 74 LIST OF DESERVING PEOPLES
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Sr No
# Name
# Father Name
# NIC NO.
# Address / Village Council
# Contact No.
# Category
# None
# None
# Program
# None
# Status
# None
# None
# None
# None
# None
# None
# None
# Disable
# Widow
# Orphan
# BISP
# Ehsaas
# Approved
# Not Approved
# 1
# Mudasir
# Inadu Rehman
# 1730122924683
# ShakrPura
# 3109493122
# None
# None
# None
# None
# None
# None
# None
# 2
# Mumtaz Ali
# Sher Ali Khan
# 17301-6141161-7
# ShakrPura
# 3147094922
# None
# None
# None
# None
# None
# None
# None
# 3
# Muhammad Aqib
# Abbas Khan
# 17301-6568322-7
# ShakrPura
# 3338644715
# None
# None
# None
# None
# None
# None
# None
# 4
# Irshad Ali
# Khaista Gul
# 17301-5635324-9
# ShakrPura
# 3169758541
# None
# None
# None
# None
# None
# None
# None
# 5
# ShehBaz Khan
# Fazal Rehman
# 17301-1608768-3
# ShakrPura
# 3109888379
# None
# None
# None
# None
# None
# None
# None
# 6
# ...
