# %%
import pandas as pd
df = pd.read_csv('AI Absent Students.csv')
df.head(13)
#df.describe()
#df_drop = df.drop("Unnamed: 7", axis = 1)
#print(df_drop)
# Out:
#     S.No       Id               Name          F.Name           CNIC  \
# 0      1   459691          Ahsan Ali    Naveed Ahmad  1730160935091
# 1      2   476576     Muhammad Qasim     Abdul karim  1430164581711
# 2      3   645496      Syed Abdullah      Faridullah  1730146761353
# 3      4   806158  Mehmood Ayaz Khan       Ayaz Khan  1730196690299
# 4      5   868638    Umar Abbas khan    Alamgir khan  1730159991813
# 5      6   983666          Abbas Ali      Arshad Ali  1720170935799
# 6      7   994235     MUHAMMAD TALHA   JEHANGIR KHAN  1720204300351
# 7      8  1002636     Sheryar Fakhar   Fakher E Alam  1730168531117
# 8      9  1129244     Muhammad Osama  Siyar Muhammad  1710187495571
# 9     10   569704               Aqsa    Abdul Wadood  1730139627304
# 10    11   590588     MUHAMMAD HARIS      ZIARAT GUL  1730131149463
# 11    12   880672     Mahnoor Sajjad    Sajjad Ahmad  1730147128290
# 12    13  1032292       Yahya Rehman  Muhammad Ajmal  1730184787485
#
# ...

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('AI Absent Students.csv')

# Create a pandas Series with the desired values
list = pd.Series(["foo", "bar", "foo", "bar", "foo", "bar", "foo", "bar", "foo", "bar", "foo", "bar", "foo","khan","Jan"])

# Assign the new column to the DataFrame
df_add = df.assign(list=list)

# Print the DataFrame with the new column
print(df_add)

df_rename = df.copy()                                
df_rename.columns = ["x1", "x2", "x3", "x4","x5", "x6", "x7", "x8"]   
print(df_rename) 

df['Id'].plot()
# Out:
#     S.No       Id                 Name           F.Name           CNIC  \
# 0      1   459691            Ahsan Ali     Naveed Ahmad  1730160935091
# 1      2   476576       Muhammad Qasim      Abdul karim  1430164581711
# 2      3   645496        Syed Abdullah       Faridullah  1730146761353
# 3      4   806158    Mehmood Ayaz Khan        Ayaz Khan  1730196690299
# 4      5   868638      Umar Abbas khan     Alamgir khan  1730159991813
# 5      6   983666            Abbas Ali       Arshad Ali  1720170935799
# 6      7   994235       MUHAMMAD TALHA    JEHANGIR KHAN  1720204300351
# 7      8  1002636       Sheryar Fakhar    Fakher E Alam  1730168531117
# 8      9  1129244       Muhammad Osama   Siyar Muhammad  1710187495571
# 9     10   569704                 Aqsa     Abdul Wadood  1730139627304
# 10    11   590588       MUHAMMAD HARIS       ZIARAT GUL  1730131149463
# 11    12   880672       Mahnoor Sajjad     Sajjad Ahmad  1730147128290
# ...
